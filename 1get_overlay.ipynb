# %%
from PIL import Image
import numpy as np
import os
import glob

# Create output directory
os.makedirs("./data/overlay", exist_ok=True)

# Get all .tiff and .tif files from images directory
image_files = glob.glob("./data/images/*.tiff") + glob.glob("./data/images/*.tif")

print(f"Found {len(image_files)} image files to process\n")

for img_path in image_files:
    # Get base filename (without path and extension)
    base_name = os.path.splitext(os.path.basename(img_path))[0]
    
    # Try to find corresponding mask with either extension
    mask_path = None
    for mask_ext in ['_masks.tif', '_masks.tiff']:
        candidate_path = f"./data/instance_masks/{base_name}{mask_ext}"
        if os.path.exists(candidate_path):
            mask_path = candidate_path
            break
    
    # Check if mask exists
    if mask_path is None:
        print(f"Warning: Mask not found for {base_name}, skipping...")
        continue
    
    print(f"Processing: {base_name}")
    
    # Load original image
    img = Image.open(img_path)
    img_np = np.array(img)

    # Load mask
    mask = Image.open(mask_path)
    mask_np = np.array(mask)

    # If mask is RGB, take one channel
    if mask_np.ndim == 3:
        mask_np = mask_np[..., 0]

    # Normalize image for display - improved version with subtle contrast enhancement
    if img.mode not in ['RGB', 'L', 'RGBA']:
        if img.mode in ['I', 'I;16', 'F']:
            # Normalize 16-bit or float images to 8-bit with subtle contrast stretching
            img_array = img_np.copy().astype(np.float32)
            
            # Use gentler percentile-based contrast stretching
            p_low = np.percentile(img_array, 0.5)
            p_high = np.percentile(img_array, 99.5)
            
            # Clip and normalize
            img_array = np.clip(img_array, p_low, p_high)
            img_array = ((img_array - p_low) / (p_high - p_low) * 255).astype(np.uint8)
            
            img = Image.fromarray(img_array, mode='L')
            img_disp = img_array
        else:
            img = img.convert('L')
            img_disp = np.array(img)
    else:
        # Apply subtle contrast stretching to 8-bit images too
        img_array = img_np.copy().astype(np.float32)
        p_low = np.percentile(img_array, 0.5)
        p_high = np.percentile(img_array, 99.5)
        img_array = np.clip(img_array, p_low, p_high)
        img_disp = ((img_array - p_low) / (p_high - p_low) * 255).astype(np.uint8)

    print(f"  Image shape: {img_np.shape}, dtype: {img_np.dtype}, mode: {img.mode}")
    print(f"  Mask shape: {mask_np.shape}, unique values: {len(np.unique(mask_np))}")

    # -----------------------
    # Pre-compute colors for ALL objects (fixed seed for consistency)
    # -----------------------
    rng = np.random.default_rng(42)  # Fixed seed
    all_instance_ids = np.unique(mask_np)
    color_map = {}
    for instance_id in all_instance_ids:
        if instance_id == 0:  # Skip background
            continue
        color_map[instance_id] = rng.random(3)

    print(f"  Created color map for {len(color_map)} unique objects")

    # -----------------------
    # Create full image overlay
    # -----------------------
    rgb_mask_full = np.zeros((*mask_np.shape, 3), dtype=np.float32)
    for instance_id in np.unique(mask_np):
        if instance_id == 0:
            continue
        rgb_mask_full[mask_np == instance_id] = color_map[instance_id]

    # Create full overlay
    overlay_full = np.stack([img_disp, img_disp, img_disp], axis=-1).astype(np.float32) / 255.0
    overlay_full = overlay_full * 0.6 + rgb_mask_full * 0.4
    overlay_full = (overlay_full * 255).astype(np.uint8)

    # Save full overlay with same filename
    output_path = f"./data/overlay/{base_name}_overlay.tif"
    Image.fromarray(overlay_full).save(output_path)
    print(f"  Saved overlay to {output_path}\n")

print("All files processed!")
# Out:
# Found 42 image files to process
#
# Processing: 20260212_085927_petiole13__00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1162
#   Created color map for 1161 unique objects
#   Saved overlay to ./data/overlay/20260212_085927_petiole13__00100_overlay.tif
#
# Processing: 20260213_094204_petiole38_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 258
#   Created color map for 257 unique objects
#   Saved overlay to ./data/overlay/20260213_094204_petiole38_00100_overlay.tif
#
# Processing: 20211222_094342_petiole_test_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1655
#   Created color map for 1654 unique objects
#   Saved overlay to ./data/overlay/20211222_094342_petiole_test_00100_overlay.tif
#
# Processing: 20211222_125057_petiole4_00400
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 2547
#   Created color map for 2546 unique objects
#   Saved overlay to ./data/overlay/20211222_125057_petiole4_00400_overlay.tif
#
# Processing: 20211222_104840_petiole_test2_00300
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 2357
#   Created color map for 2356 unique objects
#   Saved overlay to ./data/overlay/20211222_104840_petiole_test2_00300_overlay.tif
#
# Processing: 20211222_104840_petiole_test2_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1991
#   Created color map for 1990 unique objects
#   Saved overlay to ./data/overlay/20211222_104840_petiole_test2_00100_overlay.tif
#
# Processing: 20211222_113313_petiole3_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1762
#   Created color map for 1761 unique objects
#   Saved overlay to ./data/overlay/20211222_113313_petiole3_00100_overlay.tif
#
# Processing: 20260212_092402_petiole15_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 303
#   Created color map for 302 unique objects
#   Saved overlay to ./data/overlay/20260212_092402_petiole15_00100_overlay.tif
#
# Processing: 20211222_104840_petiole_test2_00400
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 2434
#   Created color map for 2433 unique objects
#   Saved overlay to ./data/overlay/20211222_104840_petiole_test2_00400_overlay.tif
#
# Processing: 20260213_145242_petiole47_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1432
#   Created color map for 1431 unique objects
#   Saved overlay to ./data/overlay/20260213_145242_petiole47_00100_overlay.tif
#
# Processing: 20211222_125057_petiole4_00300
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 2427
#   Created color map for 2426 unique objects
#   Saved overlay to ./data/overlay/20211222_125057_petiole4_00300_overlay.tif
#
# Processing: 20211222_104840_petiole_test2_00500
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 2566
#   Created color map for 2565 unique objects
#   Saved overlay to ./data/overlay/20211222_104840_petiole_test2_00500_overlay.tif
#
# Processing: 20260212_170127_petiole34_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 208
#   Created color map for 207 unique objects
#   Saved overlay to ./data/overlay/20260212_170127_petiole34_00100_overlay.tif
#
# Processing: 20260211_162350_petiole10_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1447
#   Created color map for 1446 unique objects
#   Saved overlay to ./data/overlay/20260211_162350_petiole10_00100_overlay.tif
#
# Processing: 20260213_105407_petiole41_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 981
#   Created color map for 980 unique objects
#   Saved overlay to ./data/overlay/20260213_105407_petiole41_00100_overlay.tif
#
# Processing: 20211222_125057_petiole4_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 2294
#   Created color map for 2293 unique objects
#   Saved overlay to ./data/overlay/20211222_125057_petiole4_00100_overlay.tif
#
# Processing: 20260213_164616_petiole51_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 741
#   Created color map for 740 unique objects
#   Saved overlay to ./data/overlay/20260213_164616_petiole51_00100_overlay.tif
#
# Processing: 20260212_133951_petiole30_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1202
#   Created color map for 1201 unique objects
#   Saved overlay to ./data/overlay/20260212_133951_petiole30_00100_overlay.tif
#
# Processing: 20211222_094342_petiole_test_00300
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1792
#   Created color map for 1791 unique objects
#   Saved overlay to ./data/overlay/20211222_094342_petiole_test_00300_overlay.tif
#
# Processing: 20260213_133052_petiole44_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1977
#   Created color map for 1976 unique objects
#   Saved overlay to ./data/overlay/20260213_133052_petiole44_00100_overlay.tif
#
# Processing: 20260213_102726_petiole40_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 689
#   Created color map for 688 unique objects
#   Saved overlay to ./data/overlay/20260213_102726_petiole40_00100_overlay.tif
#
# Processing: 20260211_125444_petiole1_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 230
#   Created color map for 229 unique objects
#   Saved overlay to ./data/overlay/20260211_125444_petiole1_00100_overlay.tif
#
# Processing: 20260213_100247_petiole39_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1277
#   Created color map for 1276 unique objects
#   Saved overlay to ./data/overlay/20260213_100247_petiole39_00100_overlay.tif
#
# Processing: 20211222_125057_petiole4_00500
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 2492
#   Created color map for 2491 unique objects
#   Saved overlay to ./data/overlay/20211222_125057_petiole4_00500_overlay.tif
#
# Processing: 20211222_113313_petiole3_00300
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1969
#   Created color map for 1968 unique objects
#   Saved overlay to ./data/overlay/20211222_113313_petiole3_00300_overlay.tif
#
# Processing: 20211222_113313_petiole3_00500
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 2215
#   Created color map for 2214 unique objects
#   Saved overlay to ./data/overlay/20211222_113313_petiole3_00500_overlay.tif
#
# Processing: 20211222_113313_petiole3_00200
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1852
#   Created color map for 1851 unique objects
#   Saved overlay to ./data/overlay/20211222_113313_petiole3_00200_overlay.tif
#
# Processing: 20260213_113115_petiole42_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 715
#   Created color map for 714 unique objects
#   Saved overlay to ./data/overlay/20260213_113115_petiole42_00100_overlay.tif
#
# Processing: 20211222_094342_petiole_test_00200
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1791
#   Created color map for 1790 unique objects
#   Saved overlay to ./data/overlay/20211222_094342_petiole_test_00200_overlay.tif
#
# Processing: 20260212_151430_petiole33_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 353
#   Created color map for 352 unique objects
#   Saved overlay to ./data/overlay/20260212_151430_petiole33_00100_overlay.tif
#
# Processing: 20260211_134340_petiole3_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 782
#   Created color map for 781 unique objects
#   Saved overlay to ./data/overlay/20260211_134340_petiole3_00100_overlay.tif
#
# Processing: 20260211_150303_petiole6_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1826
#   Created color map for 1825 unique objects
#   Saved overlay to ./data/overlay/20260211_150303_petiole6_00100_overlay.tif
#
# Processing: 20211222_094342_petiole_test_00400
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1874
#   Created color map for 1873 unique objects
#   Saved overlay to ./data/overlay/20211222_094342_petiole_test_00400_overlay.tif
#
# Processing: 20260213_115508_petiole43_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 392
#   Created color map for 391 unique objects
#   Saved overlay to ./data/overlay/20260213_115508_petiole43_00100_overlay.tif
#
# Processing: 20211222_104840_petiole_test2_00200
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 2211
#   Created color map for 2210 unique objects
#   Saved overlay to ./data/overlay/20211222_104840_petiole_test2_00200_overlay.tif
#
# Processing: 20211222_113313_petiole3_00400
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1943
#   Created color map for 1942 unique objects
#   Saved overlay to ./data/overlay/20211222_113313_petiole3_00400_overlay.tif
#
# Processing: 20260211_151737_petiole7_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1213
#   Created color map for 1212 unique objects
#   Saved overlay to ./data/overlay/20260211_151737_petiole7_00100_overlay.tif
#
# Processing: 20260212_174538_petiole36_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1285
#   Created color map for 1284 unique objects
#   Saved overlay to ./data/overlay/20260212_174538_petiole36_00100_overlay.tif
#
# Processing: 20260212_121724_petiole28_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 496
#   Created color map for 495 unique objects
#   Saved overlay to ./data/overlay/20260212_121724_petiole28_00100_overlay.tif
#
# Processing: 20211222_125057_petiole4_00200
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 2379
#   Created color map for 2378 unique objects
#   Saved overlay to ./data/overlay/20211222_125057_petiole4_00200_overlay.tif
#
# Processing: 20260211_175721_petiole12_00100
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1544
#   Created color map for 1543 unique objects
#   Saved overlay to ./data/overlay/20260211_175721_petiole12_00100_overlay.tif
#
# Processing: 20211222_094342_petiole_test_00500
#   Image shape: (2560, 2560), dtype: float32, mode: L
#   Mask shape: (2560, 2560), unique values: 1822
#   Created color map for 1821 unique objects
#   Saved overlay to ./data/overlay/20211222_094342_petiole_test_00500_overlay.tif
#
# All files processed!

# %%
import numpy as np
from PIL import Image
import cv2
from pathlib import Path


def find_class_contours(semantic_mask, class_id):
    """
    Find contours for a specific class in the semantic mask.
    
    Args:
        semantic_mask: semantic segmentation mask
        class_id: the class ID to find contours for
    
    Returns:
        list of contours
    """
    # Create binary mask for this class
    binary_mask = (semantic_mask == class_id).astype(np.uint8)
    
    # Find contours
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    return contours


def draw_polygons_on_image(img_normalized, semantic_mask, class_colors):
    """
    Draw polygon boundaries for each class on the normalized image.
    
    Args:
        img_normalized: normalized grayscale image
        semantic_mask: semantic segmentation mask
        class_colors: dictionary mapping class IDs to RGB colors
    
    Returns:
        image with polygons drawn
    """
    # Convert to RGB if grayscale
    if len(img_normalized.shape) == 2:
        img_with_polygons = np.stack([img_normalized] * 3, axis=-1)
    else:
        img_with_polygons = img_normalized.copy()
    
    # Get unique classes (excluding background class 0)
    unique_classes = np.unique(semantic_mask)
    unique_classes = unique_classes[unique_classes != 0]
    
    # Draw contours for each class
    for class_id in unique_classes:
        contours = find_class_contours(semantic_mask, class_id)
        color = class_colors.get(int(class_id), [255, 255, 255])
        
        # Draw contours with thick lines
        cv2.drawContours(img_with_polygons, contours, -1, color, thickness=3)
    
    return img_with_polygons


def visualize_and_save(original_img, semantic_mask, output_path, norm_images_dir):
    """
    Visualize semantic mask as overlay on original image and save both.
    
    Args:
        original_img: original image array
        semantic_mask: semantic segmentation mask
        output_path: path to save the semantic mask
        norm_images_dir: directory to save normalized images
    """
    # Define colors for each class
    class_colors = {
        0: [128, 128, 128],  # Gray - Background
        1: [0, 0, 255],      # Blue - Cortex
        2: [0, 255, 0],      # Green - Phloem Fibers
        3: [128, 0, 128],    # Purple - Phloem
        4: [255, 0, 0],      # Red - Hydrated Xylem vessels
        5: [255, 255, 0],    # Yellow - Air-based Pith cells
        6: [255, 165, 0],    # Orange - Water-based Pith cells
        7: [0, 199, 190],    # Blue turquoise - Dehydrated Xylem vessels
    }
    
    # Create colored semantic mask
    h, w = semantic_mask.shape
    colored_mask = np.zeros((h, w, 3), dtype=np.uint8)
    
    for class_id, color in class_colors.items():
        colored_mask[semantic_mask == class_id] = color
    
    # Print class distribution
    unique_classes = np.unique(semantic_mask)
    print(f"Classes present: {unique_classes}")
    for class_id in unique_classes:
        pixel_count = np.sum(semantic_mask == class_id)
        print(f"Class {class_id}: {pixel_count} pixels")
    
    # Normalize original image
    img_array = original_img.copy().astype(np.float32)
    
    # Use percentile-based contrast stretching
    p_low = np.percentile(img_array, 0.5)
    p_high = np.percentile(img_array, 99.5)
    
    # Clip and normalize
    img_array = np.clip(img_array, p_low, p_high)
    img_normalized = ((img_array - p_low) / (p_high - p_low) * 255).astype(np.uint8)
    
    # Save normalized image
    norm_image_path = norm_images_dir / f"{output_path.stem.replace('_semantic_mask', '')}_normalized.png"
    Image.fromarray(img_normalized).save(norm_image_path)
    print(f"Normalized image saved to: {norm_image_path}")
    
    # Convert to RGB if grayscale
    if len(img_normalized.shape) == 2:
        img_normalized_rgb = np.stack([img_normalized] * 3, axis=-1)
    else:
        img_normalized_rgb = img_normalized
    
    # Create overlay with transparency
    alpha = 0.2
    overlay = cv2.addWeighted(img_normalized_rgb, 1-alpha, colored_mask, alpha, 0)
    
    # Draw polygons on normalized image
    img_with_polygons = draw_polygons_on_image(img_normalized, semantic_mask, class_colors)
    
    # Save colored semantic mask (same colors as overlay)
    Image.fromarray(colored_mask).save(output_path)
    print(f"Colored semantic mask saved to: {output_path}")
    
    # Save overlay image in the same directory
    overlay_path = output_path.parent / f"{output_path.stem}_overlay.png"
    Image.fromarray(overlay).save(overlay_path)
    print(f"Overlay image saved to: {overlay_path}")
    
    # Save image with polygons
    polygon_path = output_path.parent / f"{output_path.stem}_polygons.png"
    Image.fromarray(img_with_polygons).save(polygon_path)
    print(f"Image with polygons saved to: {polygon_path}")


def process_single_file(image_path, mask_path, output_path, norm_images_dir):
    """
    Process a single image and mask file to create overlay visualization.
    
    Args:
        image_path: path to the original image
        mask_path: path to the .npy mask file
        output_path: path to save the semantic mask
        norm_images_dir: directory to save normalized images
    """
    print(f"\n{'='*80}")
    print(f"Processing: {Path(image_path).name}")
    print(f"{'='*80}")
    
    # Load image
    original_img = np.array(Image.open(image_path))
    print(f"Image shape: {original_img.shape}")
    
    # Load mask
    semantic_mask = np.load(mask_path)
    print(f"Mask shape: {semantic_mask.shape}")
    
    # Visualize and save
    print("\nVisualizing and saving...")
    visualize_and_save(original_img, semantic_mask, output_path, norm_images_dir)


def batch_process(images_dir, masks_dir, output_dir, norm_images_dir):
    """
    Process all matching files in the specified directories.
    
    Args:
        images_dir: directory containing image files (.tiff or .tif)
        masks_dir: directory containing mask files (*_mask.npy)
        output_dir: directory to save semantic masks and overlays
        norm_images_dir: directory to save normalized images
    """
    # Create output directories if they don't exist
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    
    norm_images_dir = Path(norm_images_dir)
    norm_images_dir.mkdir(parents=True, exist_ok=True)
    
    # Get all image files
    images_dir = Path(images_dir)
    image_files = list(images_dir.glob("*.tiff")) + list(images_dir.glob("*.tif"))
    
    print(f"Found {len(image_files)} image files")
    
    processed_count = 0
    skipped_count = 0
    
    for image_path in sorted(image_files):
        base_name = image_path.stem
        
        # Find corresponding mask file
        masks_dir_path = Path(masks_dir)
        mask_path = masks_dir_path / f"{base_name}_mask.npy"
        
        # Check if mask file exists
        if not mask_path.exists():
            print(f"\nSkipping {base_name}: mask file not found")
            skipped_count += 1
            continue
        
        # Output path for semantic mask (will also save overlay in same directory)
        output_path = output_dir / f"{base_name}_semantic_mask.png"
        
        # Process the files
        try:
            process_single_file(image_path, mask_path, output_path, norm_images_dir)
            processed_count += 1
        except Exception as e:
            print(f"\nError processing {base_name}: {str(e)}")
            import traceback
            traceback.print_exc()
            skipped_count += 1
    
    print(f"\n{'='*80}")
    print(f"Batch processing complete!")
    print(f"Processed: {processed_count} files")
    print(f"Skipped: {skipped_count} files")
    print(f"{'='*80}")


if __name__ == "__main__":
    # Batch process all files
    images_dir = "./data/images"
    masks_dir = "./data/annotations"  # Directory containing *_mask.npy files
    output_dir = "./data/semantic_masks"
    norm_images_dir = "./data/norm_images"
    
    batch_process(images_dir, masks_dir, output_dir, norm_images_dir)
# Out:
# Found 42 image files
#
# ================================================================================
# Processing: 20211222_094342_petiole_test_00100.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   5   6   7 255]
# Class 0: 2579713 pixels
# Class 1: 1967519 pixels
# Class 2: 26287 pixels
# Class 3: 133760 pixels
# Class 4: 406341 pixels
# Class 5: 117568 pixels
# Class 6: 925238 pixels
# Class 7: 67531 pixels
# Class 255: 329643 pixels
# Normalized image saved to: data/norm_images/20211222_094342_petiole_test_00100_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20211222_094342_petiole_test_00100_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20211222_094342_petiole_test_00100_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20211222_094342_petiole_test_00100_semantic_mask_polygons.png
#
# ================================================================================
# Processing: 20211222_094342_petiole_test_00200.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   5   6   7 255]
# Class 0: 2641755 pixels
# Class 1: 1975215 pixels
# Class 2: 26783 pixels
# Class 3: 136962 pixels
# Class 4: 415158 pixels
# Class 5: 94680 pixels
# Class 6: 915006 pixels
# Class 7: 75972 pixels
# Class 255: 272069 pixels
# Normalized image saved to: data/norm_images/20211222_094342_petiole_test_00200_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20211222_094342_petiole_test_00200_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20211222_094342_petiole_test_00200_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20211222_094342_petiole_test_00200_semantic_mask_polygons.png
#
# ================================================================================
# Processing: 20211222_094342_petiole_test_00300.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   5   6   7 255]
# Class 0: 2572510 pixels
# Class 1: 1933995 pixels
# Class 2: 28127 pixels
# Class 3: 139595 pixels
# Class 4: 345212 pixels
# Class 5: 106376 pixels
# Class 6: 931138 pixels
# Class 7: 76330 pixels
# Class 255: 420317 pixels
# Normalized image saved to: data/norm_images/20211222_094342_petiole_test_00300_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20211222_094342_petiole_test_00300_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20211222_094342_petiole_test_00300_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20211222_094342_petiole_test_00300_semantic_mask_polygons.png
#
# ================================================================================
# Processing: 20211222_094342_petiole_test_00400.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   5   6   7 255]
# Class 0: 2498138 pixels
# Class 1: 1928485 pixels
# Class 2: 28176 pixels
# Class 3: 145940 pixels
# Class 4: 408002 pixels
# Class 5: 76982 pixels
# Class 6: 923391 pixels
# Class 7: 83588 pixels
# Class 255: 460898 pixels
# Normalized image saved to: data/norm_images/20211222_094342_petiole_test_00400_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20211222_094342_petiole_test_00400_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20211222_094342_petiole_test_00400_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20211222_094342_petiole_test_00400_semantic_mask_polygons.png
#
# ================================================================================
# Processing: 20211222_094342_petiole_test_00500.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   5   6   7 255]
# Class 0:
00100_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20260213_102726_petiole40_00100_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20260213_102726_petiole40_00100_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20260213_102726_petiole40_00100_semantic_mask_polygons.png
#
# ================================================================================
# Processing: 20260213_105407_petiole41_00100.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   5   6 255]
# Class 0: 1391522 pixels
# Class 1: 1076303 pixels
# Class 2: 37306 pixels
# Class 3: 43434 pixels
# Class 4: 711460 pixels
# Class 5: 795016 pixels
# Class 6: 1899845 pixels
# Class 255: 598714 pixels
# Normalized image saved to: data/norm_images/20260213_105407_petiole41_00100_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20260213_105407_petiole41_00100_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20260213_105407_petiole41_00100_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20260213_105407_petiole41_00100_semantic_mask_polygons.png
#
# ================================================================================
# Processing: 20260213_113115_petiole42_00100.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   5   6   7 255]
# Class 0: 1365144 pixels
# Class 1: 1033922 pixels
# Class 2: 41735 pixels
# Class 3: 89987 pixels
# Class 4: 778223 pixels
# Class 5: 827046 pixels
# Class 6: 1651357 pixels
# Class 7: 177299 pixels
# Class 255: 588887 pixels
# Normalized image saved to: data/norm_images/20260213_113115_petiole42_00100_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20260213_113115_petiole42_00100_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20260213_113115_petiole42_00100_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20260213_113115_petiole42_00100_semantic_mask_polygons.png
#
# ================================================================================
# Processing: 20260213_115508_petiole43_00100.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   5   6   7 255]
# Class 0: 1326015 pixels
# Class 1: 1030670 pixels
# Class 2: 22345 pixels
# Class 3: 54463 pixels
# Class 4: 694485 pixels
# Class 5: 898491 pixels
# Class 6: 1639553 pixels
# Class 7: 280407 pixels
# Class 255: 607171 pixels
# Normalized image saved to: data/norm_images/20260213_115508_petiole43_00100_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20260213_115508_petiole43_00100_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20260213_115508_petiole43_00100_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20260213_115508_petiole43_00100_semantic_mask_polygons.png
#
# ================================================================================
# Processing: 20260213_133052_petiole44_00100.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   6   7 255]
# Class 0: 1528584 pixels
# Class 1: 949109 pixels
# Class 2: 57984 pixels
# Class 3: 114907 pixels
# Class 4: 1129677 pixels
# Class 6: 2275622 pixels
# Class 7: 21390 pixels
# Class 255: 476327 pixels
# Normalized image saved to: data/norm_images/20260213_133052_petiole44_00100_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20260213_133052_petiole44_00100_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20260213_133052_petiole44_00100_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20260213_133052_petiole44_00100_semantic_mask_polygons.png
#
# ================================================================================
# Processing: 20260213_145242_petiole47_00100.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   6   7 255]
# Class 0: 1459067 pixels
# Class 1: 1034500 pixels
# Class 2: 76195 pixels
# Class 3: 108284 pixels
# Class 4: 952017 pixels
# Class 6: 2223193 pixels
# Class 7: 216627 pixels
# Class 255: 483717 pixels
# Normalized image saved to: data/norm_images/20260213_145242_petiole47_00100_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20260213_145242_petiole47_00100_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20260213_145242_petiole47_00100_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20260213_145242_petiole47_00100_semantic_mask_polygons.png
#
# ================================================================================
# Processing: 20260213_164616_petiole51_00100.tiff
# ================================================================================
# Image shape: (2560, 2560)
# Mask shape: (2560, 2560)
#
# Visualizing and saving...
# Classes present: [  0   1   2   3   4   6   7 255]
# Class 0: 2139262 pixels
# Class 1: 1073679 pixels
# Class 2: 101863 pixels
# Class 3: 142048 pixels
# Class 4: 739638 pixels
# Class 6: 1627599 pixels
# Class 7: 234002 pixels
# Class 255: 495509 pixels
# Normalized image saved to: data/norm_images/20260213_164616_petiole51_00100_normalized.png
# Colored semantic mask saved to: data/semantic_masks/20260213_164616_petiole51_00100_semantic_mask.png
# Overlay image saved to: data/semantic_masks/20260213_164616_petiole51_00100_semantic_mask_overlay.png
# Image with polygons saved to: data/semantic_masks/20260213_164616_petiole51_00100_semantic_mask_polygons.png
#
# ================================================================================
# Batch processing complete!
# Processed: 42 files
# Skipped: 0 files
# ================================================================================
